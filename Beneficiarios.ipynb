# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'beneficiarios_ene_jun_2019.csv' 
doc = pd.read_csv(path, encoding = 'unicode_escape')
doc.head()
# Out:
#    Número Donacion Organo/Tejido    Estatus  Mes/Año de Estatus       Sexo   \
# 0     1.0  Cadaver        Córnea        Baja               1/19   Femenino
# 1     2.0  Cadaver        Córnea        Baja               1/19   Femenino
# 2     3.0  Cadaver        Córnea   En espera               1/19  Masculino
# 3     4.0  Cadaver        Córnea  Trasplante               1/19  Masculino
# 4     5.0  Cadaver        Córnea  Trasplante               2/19   Femenino
#
#    Fecha Nac  Fecha Registro Comite                  Establecimiento   \
# 0  26/06/1941            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 1  04/09/1958            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 2  05/08/1990            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 3  02/04/1938            07/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 4  18/04/1934            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
#
#                             Dependencia  Edo Residencia       Edo Origen   \
# ...

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Número                  190 non-null    float64
#  1   Donacion                190 non-null    object
#  2   Organo/Tejido           190 non-null    object
#  3   Estatus                 190 non-null    object
#  4   Mes/Año de Estatus      190 non-null    object
#  5   Sexo                    190 non-null    object
#  6   Fecha Nac               190 non-null    object
#  7   Fecha Registro Comite   190 non-null    object
#  8   Establecimiento         190 non-null    object
#  9   Dependencia             190 non-null    object
#  10  Edo Residencia          190 non-null    object
#  11  Edo Origen              190 non-null    object
#  12  Diagnostico             190 non-null    object
#  13  Grupo Sanguineo         190 non-null    object
# ...

# %%
doc.shape
# Out:
# (192, 15)

# %%
doc.shape[0]
# Out:
# 192

# %%
doc.shape[1]
# Out:
# 15

# %%
doc.columns.values.tolist()
# Out:
# ['Número',
#  'Donacion',
#  'Organo/Tejido',
#  'Estatus\xa0',
#  'Mes/Año de Estatus',
#  'Sexo\xa0',
#  'Fecha Nac\xa0',
#  'Fecha Registro Comite\xa0',
#  'Establecimiento\xa0',
#  'Dependencia',
#  'Edo Residencia\xa0',
#  'Edo Origen\xa0',
#  'Diagnostico',
#  'Grupo Sanguineo\xa0',
#  'Rh\xa0']

# %%
doc.dtypes
# Out:
# Número                    float64
# Donacion                   object
# Organo/Tejido              object
# Estatus                    object
# Mes/Año de Estatus         object
# Sexo                       object
# Fecha Nac                  object
# Fecha Registro Comite      object
# Establecimiento            object
# Dependencia                object
# Edo Residencia             object
# Edo Origen                 object
# Diagnostico                object
# Grupo Sanguineo            object
# Rh                         object
# dtype: object

# %%
doc.isnull().any().any()
# Out:
# True

# %%
msno.matrix(doc)

# %%
doc.columns[doc.isnull().any()].tolist()
# Out:
# ['Número',
#  'Donacion',
#  'Organo/Tejido',
#  'Estatus\xa0',
#  'Mes/Año de Estatus',
#  'Sexo\xa0',
#  'Fecha Nac\xa0',
#  'Fecha Registro Comite\xa0',
#  'Establecimiento\xa0',
#  'Dependencia',
#  'Edo Residencia\xa0',
#  'Edo Origen\xa0',
#  'Diagnostico',
#  'Grupo Sanguineo\xa0',
#  'Rh\xa0']

# %%
doc.describe()
# Out:
#            Número
# count  190.000000
# mean    95.500000
# std     54.992424
# min      1.000000
# 25%     48.250000
# 50%     95.500000
# 75%    142.750000
# max    190.000000

# %%
doc.loc[[0]]
# Out:
#    Número Donacion Organo/Tejido Estatus  Mes/Año de Estatus      Sexo   \
# 0     1.0  Cadaver        Córnea     Baja               1/19  Femenino
#
#    Fecha Nac  Fecha Registro Comite                  Establecimiento   \
# 0  26/06/1941            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
#
#                             Dependencia  Edo Residencia      Edo Origen   \
# 0  Instituto Mexicano del Seguro Social  San Luis Potosí  Aguascalientes
#
#                    Diagnostico Grupo Sanguineo         Rh
# 0  FALLA PRIMARIA DEL INJERTO                O   Positivo

# %%
doc.Donacion.loc[[100]]
# Out:
# 100    Cadaver
# Name: Donacion, dtype: object

# %%
doc[["Donacion","Organo/Tejido"]].loc[[20]]
# Out:
#    Donacion Organo/Tejido
# 20     Vivo         Riñón

# %%
doc.loc[100:120]
# Out:
#      Número Donacion Organo/Tejido    Estatus  Mes/Año de Estatus       Sexo   \
# 100   101.0  Cadaver        Córnea   En espera               5/19  Masculino
# 101   102.0  Cadaver        Córnea   En espera               5/19  Masculino
# 102   103.0  Cadaver        Córnea   En espera               5/19   Femenino
# 103   104.0  Cadaver        Córnea   En espera               5/19  Masculino
# 104   105.0  Cadaver        Córnea  Trasplante               2/19   Femenino
# 105   106.0  Cadaver        Córnea  Trasplante               5/19  Masculino
# 106   107.0  Cadaver         Riñón   En espera               5/19   Femenino
# 107   108.0  Cadaver         Riñón   En espera               5/19  Masculino
# 108   109.0  Cadaver         Riñón   En espera               5/19   Femenino
# 109   110.0  Cadaver         Riñón   En espera               5/19   Femenino
# 110   111.0  Cadaver         Riñón   En espera               5/19  Masculino
# ...

# %%
doc.drop([0,24,51], axis=0).head()
# Out:
#    Número Donacion Organo/Tejido    Estatus  Mes/Año de Estatus       Sexo   \
# 1     2.0  Cadaver        Córnea        Baja               1/19   Femenino
# 2     3.0  Cadaver        Córnea   En espera               1/19  Masculino
# 3     4.0  Cadaver        Córnea  Trasplante               1/19  Masculino
# 4     5.0  Cadaver        Córnea  Trasplante               2/19   Femenino
# 5     6.0  Cadaver        Córnea  Trasplante               5/19  Masculino
#
#    Fecha Nac  Fecha Registro Comite                  Establecimiento   \
# 1  04/09/1958            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 2  05/08/1990            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 3  02/04/1938            07/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 4  18/04/1934            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 5  30/01/1953            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
#
#                             Dependencia  Edo Residencia       Edo Origen   \
# ...

# %%
doc.drop(doc.index[1:5], axis=0).head(3)
# Out:
#    Número Donacion Organo/Tejido    Estatus  Mes/Año de Estatus       Sexo   \
# 0     1.0  Cadaver        Córnea        Baja               1/19   Femenino
# 5     6.0  Cadaver        Córnea  Trasplante               5/19  Masculino
# 6     7.0  Cadaver        Córnea  Trasplante               2/19   Femenino
#
#     Fecha Nac  Fecha Registro Comite                  Establecimiento   \
# 0   26/06/1941            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 5   30/01/1953            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 6  04/04/1962             17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
#
#                             Dependencia  Edo Residencia       Edo Origen   \
# 0  Instituto Mexicano del Seguro Social  San Luis Potosí   Aguascalientes
# 5  Instituto Mexicano del Seguro Social  San Luis Potosí  San Luis Potosí
# 6  Instituto Mexicano del Seguro Social  San Luis Potosí  San Luis Potosí
#
#                    Diagnostico Grupo Sanguineo         Rh
# ...

# %%
doc.Donacion.values
# Out:
# array(['Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Vivo', 'Vivo', 'Vivo', 'Vivo', 'Vivo', 'Vivo',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Vivo', 'Vivo', 'Vivo', 'Vivo',
#        'Vivo', 'Vivo', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver',
#        'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Cadaver', 'Vivo',
#        'Vivo', 'Vivo', 'Vivo', 'Vivo', 'Cadaver', 'Cadaver', 'Cadaver',
# ...

# %%
doc[['Donacion',"Organo/Tejido"]].values
# Out:
# array([['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Riñón'],
#        ['Cadaver', 'Riñón'],
#        ['Cadaver', 'Riñón'],
#        ['Cadaver', 'Riñón'],
#        ['Cadaver', 'Riñón'],
#        ['Cadaver', 'Riñón'],
#        ['Cadaver', 'Riñón'],
#        ['Vivo', 'Riñón'],
#        ['Vivo', 'Riñón'],
#        ['Vivo', 'Riñón'],
#        ['Vivo', 'Riñón'],
#        ['Vivo', 'Riñón'],
#        ['Vivo', 'Riñón'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
#        ['Cadaver', 'Córnea'],
# ...

# %%
doc.Donacion.unique()
# Out:
# array(['Cadaver', 'Vivo', nan], dtype=object)

# %%
doc.Donacion.nunique()
# Out:
# 2

# %%
doc.Donacion.value_counts()
# Out:
# Cadaver    143
# Vivo        47
# Name: Donacion, dtype: int64

# %%
doc["Organo/Tejido"].unique()
# Out:
# array(['Córnea', 'Riñón', nan], dtype=object)

# %%
doc["Organo/Tejido"].value_counts()
# Out:
# Córnea    108
# Riñón      82
# Name: Organo/Tejido, dtype: int64

# %%
doc.agg(['count','size','nunique'])
# Out:
#          Número  Donacion  Organo/Tejido  Estatus   Mes/Año de Estatus  Sexo   \
# count       190       190            190       190                 190    190
# size        192       192            192       192                 192    192
# nunique     190         2              2         3                   7      2
#
#          Fecha Nac   Fecha Registro Comite   Establecimiento   Dependencia  \
# count           190                     190               190          190
# size            192                     192               192          192
# nunique         188                      80                 7            3
#
#          Edo Residencia   Edo Origen   Diagnostico  Grupo Sanguineo   Rh
# count                190          190          190               190  190
# size                 192          192          192               192  192
# nunique               12           13           15                 5    2

# %%
doc_sample = doc.sample(frac=0.05, random_state=1)

# %%
doc_sample.head()
# Out:
#      Número Donacion Organo/Tejido    Estatus  Mes/Año de Estatus       Sexo   \
# 44     45.0  Cadaver         Riñón  Trasplante               4/19   Femenino
# 69     70.0  Cadaver        Córnea  Trasplante               6/19  Masculino
# 161   162.0  Cadaver         Riñón  Trasplante               2/19  Masculino
# 35     36.0  Cadaver        Córnea  Trasplante               4/19   Femenino
# 182   183.0  Cadaver        Córnea  Trasplante               4/19  Masculino
#
#      Fecha Nac  Fecha Registro Comite   \
# 44   20/08/1964            10/02/2017
# 69   05/09/1965            22/03/2019
# 161  22/05/1946            15/10/2018
# 35   19/03/1949            19/02/2019
# 182  03/01/1995            19/12/2018
#
#                                       Establecimiento   \
# 44       HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"
# 69       HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"
# 161  STAR MEDICA, S. A. DE C. V. (HOSPITAL SAN LUIS...
# ...

# %%
doc.shape
# Out:
# (192, 15)

# %% [raw]
# doc_sample.shape

# %% [markdown]
# Transformacion de datos

# %%
doc_dropped = doc.dropna(subset=['Donacion'])

# %%
doc_dropped.shape
# Out:
# (190, 15)

# %%
doc_dropped.head()
# Out:
#    Número Donacion Organo/Tejido    Estatus  Mes/Año de Estatus       Sexo   \
# 0     1.0  Cadaver        Córnea        Baja               1/19   Femenino
# 1     2.0  Cadaver        Córnea        Baja               1/19   Femenino
# 2     3.0  Cadaver        Córnea   En espera               1/19  Masculino
# 3     4.0  Cadaver        Córnea  Trasplante               1/19  Masculino
# 4     5.0  Cadaver        Córnea  Trasplante               2/19   Femenino
#
#    Fecha Nac  Fecha Registro Comite                  Establecimiento   \
# 0  26/06/1941            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 1  04/09/1958            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 2  05/08/1990            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 3  02/04/1938            07/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 4  18/04/1934            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
#
#                             Dependencia  Edo Residencia       Edo Origen   \
# ...

# %%
doc_dropped.shape
# Out:
# (190, 15)

# %% [markdown]
# # Manejo de datos categoricos

# %%
list(doc['Dependencia'].unique())
# Out:
# ['Instituto Mexicano del Seguro Social',
#  'Privado',
#  'Servicios de Salud del Estado',
#  nan]

# %%
keys = list(doc['Dependencia'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'Instituto Mexicano del Seguro Social': 1,
#  'Privado': 2,
#  'Servicios de Salud del Estado': 3,
#  nan: 4}

# %%
doc['Dependencia'].replace({'Instituto Mexicano del Seguro Social': 1,
 'Privado': 2,
 'Servicios de Salud del Estado': 3,
 'nan': 4}, inplace=True )

# %%
list(doc['Dependencia'].unique())
# Out:
# [1.0, 2.0, 3.0, nan]

# %%
doc.head()
# Out:
#    Número Donacion Organo/Tejido    Estatus  Mes/Año de Estatus       Sexo   \
# 0     1.0  Cadaver        Córnea        Baja               1/19   Femenino
# 1     2.0  Cadaver        Córnea        Baja               1/19   Femenino
# 2     3.0  Cadaver        Córnea   En espera               1/19  Masculino
# 3     4.0  Cadaver        Córnea  Trasplante               1/19  Masculino
# 4     5.0  Cadaver        Córnea  Trasplante               2/19   Femenino
#
#    Fecha Nac  Fecha Registro Comite                  Establecimiento   \
# 0  26/06/1941            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 1  04/09/1958            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 2  05/08/1990            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 3  02/04/1938            07/01/2019   HOSPITAL GENERAL DE ZONA No. 50
# 4  18/04/1934            17/01/2019   HOSPITAL GENERAL DE ZONA No. 50
#
#    Dependencia  Edo Residencia       Edo Origen                   Diagnostico  \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

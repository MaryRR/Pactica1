# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'donante_ene_jun_2019.csv' 
doc = pd.read_csv(path, encoding = 'unicode_escape')
doc.head()
# Out:
#   Mes/Año ID donante Órgano/Tejido donado Hospital Generador de la Donación  \
# 0  ene-19    2019-01     CÓRNEA IZQUIERDA        HOSPITAL GENERAL DE VALLES
# 1  ene-19    2019-01       CÓRNEA DERECHA        HOSPITAL GENERAL DE VALLES
# 2  ene-19    2019-01        RIÑÓN DERECHO        HOSPITAL GENERAL DE VALLES
# 3  ene-19    2019-01      RIÑÓN IZQUIERDO        HOSPITAL GENERAL DE VALLES
# 4  ene-19    2019-01                HUESO        HOSPITAL GENERAL DE VALLES
#
#                              Hospital de destino              Edo
# 0                HOSPITAL GENERAL DE ZONA No. 50  San Luis Potosí
# 1                HOSPITAL GENERAL DE ZONA No. 50  San Luis Potosí
# 2  HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"  San Luis Potosí
# 3  HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"  San Luis Potosí
# 4            INSTITUTO MEXICANO DE BIOTECNOLOGÍA          Jalisco

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Mes/Año                            30 non-null     object
#  1   ID donante                         30 non-null     object
#  2   Órgano/Tejido donado               30 non-null     object
#  3   Hospital Generador de la Donación  30 non-null     object
#  4   Hospital de destino                30 non-null     object
#  5   Edo                                30 non-null     object
# dtypes: object(6)
# memory usage: 1.5+ KB

# %%
doc.shape
# Out:
# (30, 6)

# %%
doc.columns.values.tolist()
# Out:
# ['Mes/Año',
#  'ID donante',
#  'Órgano/Tejido donado',
#  'Hospital Generador de la Donación',
#  'Hospital de destino',
#  'Edo']

# %%
doc.dtypes
# Out:
# Mes/Año                              object
# ID donante                           object
# Órgano/Tejido donado                 object
# Hospital Generador de la Donación    object
# Hospital de destino                  object
# Edo                                  object
# dtype: object

# %%
msno.matrix(doc)

# %%
doc.describe()
# Out:
#        Mes/Año ID donante Órgano/Tejido donado  \
# count       30         30                   30
# unique       6          6                    7
# top     ene-19    2019-03     CÓRNEA IZQUIERDA
# freq        13          9                    6
#
#                     Hospital Generador de la Donación  \
# count                                              30
# unique                                              2
# top     HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"
# freq                                               15
#
#                                   Hospital de destino              Edo
# count                                              30               30
# unique                                              9                4
# top     HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"  San Luis Potosí
# freq                                               15               22

# %%
doc['Órgano/Tejido donado'].loc[[15]]
# Out:
# 15    RIÑÓN DERECHO
# Name: Órgano/Tejido donado, dtype: object

# %%
doc['Órgano/Tejido donado'].values
# Out:
# array(['CÓRNEA IZQUIERDA', 'CÓRNEA DERECHA', 'RIÑÓN DERECHO',
#        'RIÑÓN IZQUIERDO', 'HUESO', 'PIEL', 'CÓRNEA IZQUIERDA',
#        'CÓRNEA DERECHA', 'RIÑÓN DERECHO', 'RIÑÓN IZQUIERDO', 'HÍGADO',
#        'HUESO', 'PIEL', 'CÓRNEA IZQUIERDA', 'CÓRNEA DERECHA',
#        'RIÑÓN DERECHO', 'RIÑÓN IZQUIERDO', 'CÓRNEA IZQUIERDA',
#        'CÓRNEA DERECHA', 'RIÑÓN DERECHO', 'RIÑÓN IZQUIERDO', 'HUESO',
#        'RIÑÓN DERECHO', 'CÓRNEA IZQUIERDA', 'CÓRNEA DERECHA',
#        'CÓRNEA IZQUIERDA', 'CÓRNEA DERECHA', 'RIÑÓN DERECHO',
#        'RIÑÓN IZQUIERDO', 'HÍGADO'], dtype=object)

# %%
doc['Órgano/Tejido donado'].value_counts()
# Out:
# CÓRNEA IZQUIERDA    6
# RIÑÓN DERECHO       6
# CÓRNEA DERECHA      6
# RIÑÓN IZQUIERDO     5
# HUESO               3
# PIEL                2
# HÍGADO              2
# Name: Órgano/Tejido donado, dtype: int64

# %%
doc.agg(['count','size','nunique'])
# Out:
#          Mes/Año  ID donante  Órgano/Tejido donado  \
# count         30          30                    30
# size          30          30                    30
# nunique        6           6                     7
#
#          Hospital Generador de la Donación  Hospital de destino  Edo
# count                                   30                   30   30
# size                                    30                   30   30
# nunique                                  2                    9    4

# %%
keys = list(doc['Hospital Generador de la Donación'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'HOSPITAL GENERAL DE VALLES': 1,
#  'HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"': 2}

# %%
doc['Hospital Generador de la Donación'].replace({'HOSPITAL GENERAL DE VALLES': 1,
 'HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"': 2}, inplace =True )

# %%
list(doc['Hospital Generador de la Donación'].unique())
# Out:
# [1, 2]

# %%
doc.head()
# Out:
#   Mes/Año ID donante Órgano/Tejido donado  Hospital Generador de la Donación  \
# 0  ene-19    2019-01     CÓRNEA IZQUIERDA                                  1
# 1  ene-19    2019-01       CÓRNEA DERECHA                                  1
# 2  ene-19    2019-01        RIÑÓN DERECHO                                  1
# 3  ene-19    2019-01      RIÑÓN IZQUIERDO                                  1
# 4  ene-19    2019-01                HUESO                                  1
#
#                              Hospital de destino              Edo
# 0                HOSPITAL GENERAL DE ZONA No. 50  San Luis Potosí
# 1                HOSPITAL GENERAL DE ZONA No. 50  San Luis Potosí
# 2  HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"  San Luis Potosí
# 3  HOSPITAL CENTRAL "DR. IGNACIO MORONES PRIETO"  San Luis Potosí
# 4            INSTITUTO MEXICANO DE BIOTECNOLOGÍA          Jalisco

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
doc [ 'Órgano/Tejido donado' ]  =  doc [ 'Órgano/Tejido donado' ] . astype ( 'object' )

doc. plot ( kind = 'scatter' , x = 'Órgano/Tejido donado' , y = 'Edo' )

# %%
plt . hist ( doc[ 'Órgano/Tejido donado' ]) 
plt . xlabel ( 'Órgano/Tejido donado' ) 
plt . ylabel ( 'Edo' ) 
plt . título ( 'Frecuencia de tipoact' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-7b2b96ff1571> in <module>
#       2 plt . xlabel ( 'Órgano/Tejido donado' )
#       3 plt . ylabel ( 'Edo' )
# ----> 4 plt . título ( 'Frecuencia de tipoact' )
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'título'

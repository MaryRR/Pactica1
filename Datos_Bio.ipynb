# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'DA_BIO_SIS_2017.csv' 
doc = pd.read_csv(path, encoding = 'unicode_escape')
doc.head()
# Out:
#    Clave_Entidad         Entidad  Clave_Municipio       Municipio  \
# 0              1  AGUASCALIENTES                1  AGUASCALIENTES
# 1              1  AGUASCALIENTES                1  AGUASCALIENTES
# 2              1  AGUASCALIENTES                1  AGUASCALIENTES
# 3              1  AGUASCALIENTES                1  AGUASCALIENTES
# 4              1  AGUASCALIENTES                1  AGUASCALIENTES
#
#          CLUES                                       Nombre_CLUES  Mes  Anio  \
# 0  ASSSA000095                CENTRO DE SALUD URBANO CONSTITUCIÓN    5  2017
# 1  ASSSA000095                CENTRO DE SALUD URBANO CONSTITUCIÓN    8  2017
# 2  ASSSA000095                CENTRO DE SALUD URBANO CONSTITUCIÓN   11  2017
# 3  ASSSA000124  CENTRO DE SALUD URBANO LICENCIADO JOSÉ LÓPEZ P...    7  2017
# 4  ASSSA000124  CENTRO DE SALUD URBANO LICENCIADO JOSÉ LÓPEZ P...   10  2017
#
#    BIO01  BIO50  ...  BIE18  BIE19  BIE20  BIE21  BIE22  BIE23  BIE24  BIE25  \
# ...

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149238 entries, 0 to 149237
# Columns: 112 entries, Clave_Entidad to BIE27
# dtypes: float64(104), int64(4), object(4)
# memory usage: 127.5+ MB

# %%
doc.shape
# Out:
# (149238, 112)

# %%
doc.columns.values.tolist()
# Out:
# ['Clave_Entidad',
#  'Entidad',
#  'Clave_Municipio',
#  'Municipio',
#  'CLUES',
#  'Nombre_CLUES',
#  'Mes',
#  'Anio',
#  'BIO01',
#  'BIO50',
#  'BIO03',
#  'VAC01',
#  'VAC02',
#  'VAC03',
#  'VAC04',
#  'VAC05',
#  'VAC06',
#  'VAC07',
#  'VAC08',
#  'VAC09',
#  'VAC10',
#  'VAC11',
#  'BIO88',
#  'VAC12',
#  'VAC13',
#  'VAC14',
#  'VAC15',
#  'VAC16',
#  'VAC17',
#  'VAC18',
#  'VAC19',
#  'VAC20',
#  'VAC21',
#  'VAC22',
#  'VAC23',
#  'VAC24',
#  'VAC25',
#  'VAC26',
#  'VAC27',
#  'VAC28',
#  'VAC29',
#  'VAC30',
#  'VAC31',
#  'VAC32',
#  'VAC33',
#  'VAC34',
#  'VAC35',
#  'VAC36',
#  'VAC37',
#  'VAC38',
#  'VAC39',
#  'VAC40',
#  'VAC41',
#  'VAC42',
#  'VAC43',
#  'VAC44',
#  'VAC45',
#  'VAC46',
#  'VAC47',
#  'VAC48',
#  'VAC49',
#  'VAC50',
#  'VAC51',
#  'VAC52',
#  'VAC53',
#  'VAC54',
#  'VAC55',
#  'VAC56',
#  'VAC57',
#  'VAC58',
#  'VAC59',
#  'VAC60',
#  'VAC61',
#  'VAC62',
#  'VAC63',
#  'BIO48',
#  'BIO49',
#  'ZOR06',
#  'ZOR08',
#  'ZOR10',
#  'ZOR12',
# ...

# %%
doc.isnull().any().any()
# Out:
# True

# %%
msno.matrix(doc)

# %%
doc.describe()
# Out:
#        Clave_Entidad  Clave_Municipio            Mes      Anio         BIO01  \
# count  149238.000000    149238.000000  149238.000000  149238.0  34452.000000
# mean       17.190789        59.780672       6.496502    2017.0     28.852694
# std         7.716595        82.255710       3.467500       0.0     78.175243
# min         1.000000         1.000000       1.000000    2017.0      1.000000
# 25%        12.000000        12.000000       3.000000    2017.0      3.000000
# 50%        15.000000        34.000000       6.000000    2017.0      7.000000
# 75%        23.000000        74.000000      10.000000    2017.0     21.000000
# max        32.000000       570.000000      12.000000    2017.0   2106.000000
#
#               BIO50        BIO03         VAC01          VAC02          VAC03  \
# count  30138.000000  6122.000000  110800.00000  111753.000000  109866.000000
# mean       9.427600     3.220843      11.92324      11.261094      10.703903
# ...

# %%
doc[["Entidad","Municipio"]].loc[100000]
# Out:
# Entidad          JALISCO
# Municipio    SAN GABRIEL
# Name: 100000, dtype: object

# %%
doc.loc[100:104]
# Out:
#      Clave_Entidad         Entidad  Clave_Municipio       Municipio  \
# 100              1  AGUASCALIENTES                1  AGUASCALIENTES
# 101              1  AGUASCALIENTES                1  AGUASCALIENTES
# 102              1  AGUASCALIENTES                1  AGUASCALIENTES
# 103              1  AGUASCALIENTES                2        ASIENTOS
# 104              1  AGUASCALIENTES                2        ASIENTOS
#
#            CLUES                        Nombre_CLUES  Mes  Anio  BIO01  BIO50  \
# 100  ASSSA000223   CENTRO DE SALUD RURAL LOS CUERVOS    8  2017    NaN    NaN
# 101  ASSSA000264   CENTRO DE SALUD RURAL SAN IGNACIO    7  2017    NaN    NaN
# 102  ASSSA000264   CENTRO DE SALUD RURAL SAN IGNACIO   10  2017    1.0    5.0
# 103  ASSSA000392  CENTRO DE SALUD RURAL VILLA JUÁREZ    6  2017    NaN    NaN
# 104  ASSSA000392  CENTRO DE SALUD RURAL VILLA JUÁREZ    9  2017   22.0   11.0
#
#      ...  BIE18  BIE19  BIE20  BIE21  BIE22  BIE23  BIE24  BIE25  BIE26  BIE27
# ...

# %%
doc.Nombre_CLUES.unique()
# Out:
# array(['CENTRO DE SALUD URBANO CONSTITUCIÓN',
#        'CENTRO DE SALUD URBANO LICENCIADO JOSÉ LÓPEZ PORTILLO',
#        'CENTRO DE SALUD URBANO SAN MARCOS', ...,
#        'CARAVANA DE LA SALUD HUAMANTLA III', 'TOMATLAN',
#        'JURISDICCIÓN SANITARIA VIII VERACRUZ'], dtype=object)

# %%
doc.Nombre_CLUES.nunique()
# Out:
# 12726

# %%
doc.Nombre_CLUES.value_counts()
# Out:
# EMILIANO ZAPATA                                    286
# BENITO JUÁREZ                                      199
# VICENTE GUERRERO                                   127
# GUADALUPE VICTORIA                                 123
# LÁZARO CÁRDENAS                                    119
#                                                   ...
# CENTRO DE SALUD RURAL PUEBLO NUEVO ( NVO OCUCA)      1
# MODULO EL VENADO I MOD                               1
# H. B. C. DE LAS MARGARITAS                           1
# CENTRO DE SALUD RURAL BACANUCHI                      1
# HOSPITAL BÁSICO COMUNITARIO HUEHUETLA                1
# Name: Nombre_CLUES, Length: 12726, dtype: int64

# %%
keys = list(doc['Municipio'].unique())
vals = range(1,1000000)
act = dict(zip(keys, vals))
act
# Out:
# {'AGUASCALIENTES': 1,
#  'ASIENTOS': 2,
#  'CALVILLO': 3,
#  'JESÚS MARÍA': 4,
#  'RINCÓN DE ROMOS': 5,
#  'SAN JOSÉ DE GRACIA': 6,
#  'EL LLANO': 7,
#  'SAN FRANCISCO DE LOS ROMO': 8,
#  'ENSENADA': 9,
#  'PABELLÓN DE ARTEAGA': 10,
#  'TEPEZALÁ': 11,
#  'MEXICALI': 12,
#  'COSÍO': 13,
#  'TECATE': 14,
#  'TIJUANA': 15,
#  'PLAYAS DE ROSARITO': 16,
#  'MULEGÉ': 17,
#  'LA PAZ': 18,
#  'LOS CABOS': 19,
#  'CALKINÍ': 20,
#  'CAMPECHE': 21,
#  'COMONDÚ': 22,
#  'CARMEN': 23,
#  'CHAMPOTÓN': 24,
#  'HOPELCHÉN': 25,
#  'CALAKMUL': 26,
#  'CANDELARIA': 27,
#  'ACUÑA': 28,
#  'ARTEAGA': 29,
#  'LORETO': 30,
#  'HECELCHAKÁN': 31,
#  'CANDELA': 32,
#  'CASTAÑOS': 33,
#  'CUATRO CIÉNEGAS': 34,
#  'TENABO': 35,
#  'ESCÁRCEGA': 36,
#  'PALIZADA': 37,
#  'ESCOBEDO': 38,
#  'FRANCISCO I. MADERO': 39,
#  'GENERAL CEPEDA': 40,
#  'MATAMOROS': 41,
#  'ABASOLO': 42,
#  'FRONTERA': 43,
#  'JUÁREZ': 44,
#  'MONCLOVA': 45,
#  'LAMADRID': 46,
#  'NADADORES': 47,
#  'OCAMPO': 48,
#  'PIEDRAS NEGRAS': 49,
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
doc.dtypes
# Out:
# Clave_Entidad        int64
# Entidad             object
# Clave_Municipio      int64
# Municipio           object
# CLUES               object
#                     ...
# BIE23              float64
# BIE24              float64
# BIE25              float64
# BIE26              float64
# BIE27              float64
# Length: 112, dtype: object

# %%
doc[ 'Entidad' ]  =  doc [ 'Entidad' ] . astype ( 'object' )

doc.plot ( kind = 'scatter' , x = 'Entidad' , y = 'Municipio' )

# %%
plt . hist ( doc[ 'Municipio' ]) 
plt . xlabel ( 'Municipio' ) 
plt . ylabel ( 'Entidad' )
